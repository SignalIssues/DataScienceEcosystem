# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Space X  Falcon 9 First Stage Landing Prediction**

# %% [markdown]
# ## Web scraping Falcon 9 and Falcon Heavy Launches Records from Wikipedia

# %% [markdown]
# Estimated time needed: **40** minutes

# %% [markdown]
# In this lab, you will be performing web scraping to collect Falcon 9 historical launch records from a Wikipedia page titled `List of Falcon 9 and Falcon Heavy launches`
#
# https://en.wikipedia.org/wiki/List_of_Falcon_9_and_Falcon_Heavy_launches

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_1_L2/images/Falcon9_rocket_family.svg)

# %% [markdown]
# Falcon 9 first stage will land successfully

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/api/Images/landing_1.gif)

# %% [markdown]
# Several examples of an unsuccessful landing are shown here:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/api/Images/crash.gif)

# %% [markdown]
# More specifically, the launch records are stored in a HTML table shown below:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_1_L2/images/falcon9-launches-wiki.png)

# %% [markdown]
#   ## Objectives
# Web scrap Falcon 9 launch records with `BeautifulSoup`:
# - Extract a Falcon 9 launch records HTML table from Wikipedia
# - Parse the table and convert it into a Pandas data frame

# %% [markdown]
# First let's import required packages for this lab

# %%
# !pip3 install beautifulsoup4
# !pip3 install requests
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\travi\appdata\local\programs\python\python313\lib\site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\travi\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: requests in c:\users\travi\appdata\local\programs\python\python313\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\travi\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\travi\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\travi\appdata\local\programs\python\python313\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\travi\appdata\local\programs\python\python313\lib\site-packages (from requests) (2024.8.30)

# %%
import sys

import requests
from bs4 import BeautifulSoup
import re
import unicodedata
import pandas as pd

# %% [markdown]
# and we will provide some helper functions for you to process web scraped HTML table

# %%
def date_time(table_cells):
    """
    This function returns the data and time from the HTML  table cell
    Input: the  element of a table data cell extracts extra row
    """
    return [data_time.strip() for data_time in list(table_cells.strings)][0:2]

def booster_version(table_cells):
    """
    This function returns the booster version from the HTML  table cell 
    Input: the  element of a table data cell extracts extra row
    """
    out=''.join([booster_version for i,booster_version in enumerate( table_cells.strings) if i%2==0][0:-1])
    return out

def landing_status(table_cells):
    """
    This function returns the landing status from the HTML table cell 
    Input: the  element of a table data cell extracts extra row
    """
    out=[i for i in table_cells.strings][0]
    return out


def get_mass(table_cells):
    mass=unicodedata.normalize("NFKD", table_cells.text).strip()
    if mass:
        mass.find("kg")
        new_mass=mass[0:mass.find("kg")+2]
    else:
        new_mass=0
    return new_mass


def extract_column_from_header(row):
    """
    This function returns the landing status from the HTML table cell 
    Input: the  element of a table data cell extracts extra row
    """
    if (row.br):
        row.br.extract()
    if row.a:
        row.a.extract()
    if row.sup:
        row.sup.extract()
        
    colunm_name = ' '.join(row.contents)
    
    # Filter the digit and empty names
    if not(colunm_name.strip().isdigit()):
        colunm_name = colunm_name.strip()
        return colunm_name

# %% [markdown]
# To keep the lab tasks consistent, you will be asked to scrape the data from a snapshot of the  `List of Falcon 9 and Falcon Heavy launches` Wikipage updated on
# `9th June 2021`

# %%
static_url = "https://en.wikipedia.org/w/index.php?title=List_of_Falcon_9_and_Falcon_Heavy_launches&oldid=1027686922"

# %% [markdown]
# Next, request the HTML page from the above URL and get a `response` object

# %% [markdown]
# ### TASK 1: Request the Falcon9 Launch Wiki page from its URL

# %% [markdown]
# First, let's perform an HTTP GET method to request the Falcon9 Launch HTML page, as an HTTP response.

# %%
# use requests.get() method with the provided static_url
# assign the response to a object
response = requests.get(static_url)
print(response.status_code)
# Out:
# 200

# %% [markdown]
# Create a `BeautifulSoup` object from the HTML `response`

# %%
# Use BeautifulSoup() to create a BeautifulSoup object from a response text content
soup = BeautifulSoup(response.text, 'html.parser')

# %% [markdown]
# Print the page title to verify if the `BeautifulSoup` object was created properly

# %%
# Use soup.title attribute
soup.title
# Out:
# <title>List of Falcon 9 and Falcon Heavy launches - Wikipedia</title>

# %% [markdown]
# ### TASK 2: Extract all column/variable names from the HTML table header

# %% [markdown]
# Next, we want to collect all relevant column names from the HTML table header

# %% [markdown]
# Let's try to find all tables on the wiki page first. If you need to refresh your memory about `BeautifulSoup`, please check the external reference link towards the end of this lab

# %%
# Use the find_all function in the BeautifulSoup object, with element type `table`
# Assign the result to a list called `html_tables`
html_tables = soup.find_all('table')

# %% [markdown]
# Starting from the third table is our target table contains the actual launch records.

# %%
# Let's print the third table and check its content
first_launch_table = html_tables[2]
#print(first_launch_table)

# %% [markdown]
# You should able to see the columns names embedded in the table header elements `<th>` as follows:

# %% [markdown]
# ```
# <tr>
# <th scope="col">Flight No.
# </th>
# <th scope="col">Date and<br/>time (<a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">UTC</a>)
# </th>
# <th scope="col"><a href="/wiki/List_of_Falcon_9_first-stage_boosters" title="List of Falcon 9 first-stage boosters">Version,<br/>Booster</a> <sup class="reference" id="cite_ref-booster_11-0"><a href="#cite_note-booster-11">[b]</a></sup>
# </th>
# <th scope="col">Launch site
# </th>
# <th scope="col">Payload<sup class="reference" id="cite_ref-Dragon_12-0"><a href="#cite_note-Dragon-12">[c]</a></sup>
# </th>
# <th scope="col">Payload mass
# </th>
# <th scope="col">Orbit
# </th>
# <th scope="col">Customer
# </th>
# <th scope="col">Launch<br/>outcome
# </th>
# <th scope="col"><a href="/wiki/Falcon_9_first-stage_landing_tests" title="Falcon 9 first-stage landing tests">Booster<br/>landing</a>
# </th></tr>
# ```

# %% [markdown]
# Next, we just need to iterate through the `<th>` elements and apply the provided `extract_column_from_header()` to extract column name one by one

# %%
column_names = []

for th in first_launch_table.find_all('th'):
    name = extract_column_from_header(th)
    if name is not None and len(name) > 0:
        column_names.append(name)
# Apply find_all() function with `th` element on first_launch_table
# Iterate each th element and apply the provided extract_column_from_header() to get a column name
# Append the Non-empty column name (`if name is not None and len(name) > 0`) into a list called column_names

# %% [markdown]
# Check the extracted column names

# %%
print(column_names)
# Out:
# ['Flight No.', 'Date and time ( )', 'Launch site', 'Payload', 'Payload mass', 'Orbit', 'Customer', 'Launch outcome']

# %% [markdown]
# ## TASK 3: Create a data frame by parsing the launch HTML tables

# %% [markdown]
# We will create an empty dictionary with keys from the extracted column names in the previous task. Later, this dictionary will be converted into a Pandas dataframe

# %%
launch_dict= dict.fromkeys(column_names)

# Remove an irrelvant column
del launch_dict['Date and time ( )']

# Let's initial the launch_dict with each value to be an empty list
launch_dict['Flight No.'] = []
launch_dict['Launch site'] = []
launch_dict['Payload'] = []
launch_dict['Payload mass'] = []
launch_dict['Orbit'] = []
launch_dict['Customer'] = []
launch_dict['Launch outcome'] = []
# Added some new columns
launch_dict['Version Booster']=[]
launch_dict['Booster landing']=[]
launch_dict['Date']=[]
launch_dict['Time']=[]

# %% [markdown]
# Next, we just need to fill up the `launch_dict` with launch records extracted from table rows.

# %% [markdown]
# Usually, HTML tables in Wiki pages are likely to contain unexpected annotations and other types of noises, such as reference links `B0004.1[8]`, missing values `N/A [e]`, inconsistent formatting, etc.

# %% [markdown]
# To simplify the parsing process, we have provided an incomplete code snippet below to help you to fill up the `launch_dict`. Please complete the following code snippet with TODOs or you can choose to write your own logic to parse all launch tables:

# %%
extracted_row = 0
#Extract each table 
for table_number,table in enumerate(soup.find_all('table',"wikitable plainrowheaders collapsible")):
   # get table row 
    for rows in table.find_all("tr"):
        #check to see if first table heading is as number corresponding to launch a number 
        if rows.th:
            if rows.th.string:
                flight_number=rows.th.string.strip()
                flag=flight_number.isdigit()
        else:
            flag=False
        #get table element 
        row=rows.find_all('td')
        #if it is number save cells in a dictonary 
        if flag:
            extracted_row += 1
            # Flight Number value
            # TODO: Append the flight_number into launch_dict with key `Flight No.`
            launch_dict['Flight No.'].append(flight_number)
            print(f'flight_number is {flight_number}')
            datatimelist=date_time(row[0])
            
            # Date value
            # TODO: Append the date into launch_dict with key `Date`
            date = datatimelist[0].strip(',')
            launch_dict['Date'].append(date)
            print(f'Adding date {date}')
            
            # Time value
            # TODO: Append the time into launch_dict with key `Time`
            time = datatimelist[1]
            launch_dict['Time'].append(time)
            print(f'Adding time {time}')
              
            # Booster version
            # TODO: Append the bv into launch_dict with key `Version Booster`
            bv=booster_version(row[1])
            if not(bv):
                bv=row[1].a.string
            launch_dict['Version Booster'].append(bv)
            print(f'Booster Version {bv}')
            
            # Launch Site
            # TODO: Append the bv into launch_dict with key `Launch Site`
            launch_site = row[2].a.string
            launch_dict['Launch site'].append(launch_site)
            print(f'Launch Site is {launch_site}')
            
            # Payload
            # TODO: Append the payload into launch_dict with key `Payload`
            payload = row[3].a.string
            launch_dict['Payload'].append(payload)
            print(f'payload:  {payload}')
            
            # Payload Mass
            # TODO: Append the payload_mass into launch_dict with key `Payload mass`
            payload_mass = get_mass(row[4])
            launch_dict['Payload mass'].append(payload_mass)
            print(f'payload: {payload_mass}')
            
            # Orbit
            # TODO: Append the orbit into launch_dict with key `Orbit`
            orbit = row[5].a.string
            launch_dict['Orbit'].append(orbit)
            print(f'{orbit} Orbit')
            
            # Customer
            # TODO: Append the customer into launch_dict with key `Customer`
            try:
                customer = row[6].a.string
            except:
                customer = row[6].string
            launch_dict['Customer'].append(customer)
            print(f'for {customer}')
            
            # Launch outcome
            # TODO: Append the launch_outcome into launch_dict with key `Launch outcome`
            launch_outcome = list(row[7].strings)[0]
            launch_dict['Launch outcome'].append(launch_outcome)
            print(f'result:  {launch_outcome}')
            
            # Booster landing
            # TODO: Append the launch_outcome into launch_dict with key `Booster landing`
            booster_landing = landing_status(row[8])
            launch_dict['Booster landing'].append(booster_landing)
            print(f'Landing: {booster_landing}')
# Out:
# flight_number is 1
# Adding date 4 June 2010
# Adding time 18:45
# Booster Version F9 v1.07B0003.18
# Launch Site is CCAFS
# payload:  Dragon Spacecraft Qualification Unit
# payload: 0
# LEO Orbit
# for SpaceX
# result:  Success
#
# Landing: Failure
# flight_number is 2
# Adding date 8 December 2010
# Adding time 15:43
# Booster Version F9 v1.07B0004.18
# Launch Site is CCAFS
# payload:  Dragon
# payload: 0
# LEO Orbit
# for NASA
# result:  Success
# Landing: Failure
# flight_number is 3
# Adding date 22 May 2012
# Adding time 07:44
# Booster Version F9 v1.07B0005.18
# Launch Site is CCAFS
# payload:  Dragon
# payload: 525 kg
# LEO Orbit
# for NASA
# result:  Success
# Landing: No attempt
#
# flight_number is 4
# Adding date 8 October 2012
# Adding time 00:35
# Booster Version F9 v1.07B0006.18
# Launch Site is CCAFS
# payload:  SpaceX CRS-1
# payload: 4,700 kg
# LEO Orbit
# for NASA
# result:  Success
#
# Landing: No attempt
# flight_number is 5
# Adding date 1 March 2013
# Adding time 15:10
# Booster Version F9 v1.07B0007.18
# Launch Site is CCAFS
# payload:  SpaceX CRS-2
# payload: 4,877 kg
# LEO Orbit
# for NASA
# result:  Success
#
# Landing: No attempt
#
# flight_number is 6
# Adding date 29 September 2013
# Adding time 16:00
# Booster Version F9 v1.17B10038
# Launch Site is VAFB
# payload:  CASSIOPE
# payload: 500 kg
# Polar orbit Orbit
# for MDA
# result:  Success
# Landing: Uncontrolled
# flight_number is 7
# Adding date 3 December 2013
# Adding time 22:41
# Booster Version F9 v1.1
# Launch Site is CCAFS
# payload:  SES-8
# payload: 3,170 kg
# GTO Orbit
# for SES
# result:  Success
# Landing: No attempt
# flight_number is 8
# Adding date 6 January 2014
# Adding time 22:06
# Booster Version F9 v1.1
# Launch Site is CCAFS
# payload:  Thaicom 6
# payload: 3,325 kg
# GTO Orbit
# for Thaicom
# result:  Success
# Landing: No attempt
# flight_number is 9
# Adding date 18 April 2014
# Adding time 19:25
# Booster Version F9 v1.1
# Launch Site is Cape Canaveral
# payload:  SpaceX CRS-3
# payload: 2,296 kg
# LEO Orbit
# for NASA
# result:  Success
#
# Landing: Controlled
# flight_number is 10
# Adding date 14 July 2014
# Adding time 15:15
# Booster Version F9 v1.1
# Launch Site is Cape Canaveral
# payload:  Orbcomm-OG2
# payload: 1,316 kg
# LEO Orbit
# for Orbcomm
# result:  Success
# Landing: Controlled
# flight_number is 11
# Adding date 5 August 2014
# Adding time 08:00
# Booster Version F9 v1.1
# Launch Site is Cape Canaveral
# payload:  AsiaSat 8
# payload: 4,535 kg
# GTO Orbit
# for AsiaSat
# result:  Success
# Landing: No attempt
# flight_number is 12
# Adding date 7 September 2014
# Adding time 05:00
# Booster Version F9 v1.1[
# Launch Site is Cape Canaveral
# payload:  AsiaSat 6
# payload: 4,428 kg
# GTO Orbit
# for AsiaSat
# result:  Success
# Landing: No attempt
#
# flight_number is 13
# Adding date 21 September 2014
# Adding time 05:52
# Booster Version F9 v1.1[
# Launch Site is Cape Canaveral
# payload:  SpaceX CRS-4
# payload: 2,216 kg
# LEO Orbit
# for NASA
# result:  Success
# Landing: Uncontrolled
# flight_number is 14
# Adding date 10 January 2015
# Adding time 09:47
# Booster Version F9 v1.1[
# Launch Site is Cape Canaveral
# payload:  SpaceX CRS-5
# payload: 2,395 kg
# LEO Orbit
# for NASA
# result:  Success
# Landing: Failure
# flight_number is 15
# Adding date 11 February 2015
# Adding time 23:03
# Booster Version F9 v1.1[
# Launch Site is Cape Canaveral
# payload:  DSCOVR
# payload: 570 kg
# HEO Orbit
# for USAF
# result:  Success
#
# Landing: Controlled
# flight_number is 16
# Adding date 2 March 2015
# Adding time 03:50
# Booster Version F9 v1.1[
# Launch Site is Cape Canaveral
# payload:  ABS-3A
# payload: 4,159 kg
# GTO Orbit
# for ABS
# result:  Success
#
# Landing: No attempt
# flight_number is 17
# Adding date 14 April 2015
# Adding time 20:10
# Booster Version F9 v1.1[
# Launch Site is Cape Canaveral
# payload:  SpaceX CRS-6
# payload: 1,898 kg
# LEO Orbit
# for NASA
# result:  Success
#
# Landing: Failure
# flight_number is 18
# Adding date 27 April 2015
# Adding time 23:03
# Booster Version F9 v1.1[
# Launch Site is Cape Canaveral
# payload:  TürkmenÄlem 52°E / MonacoSAT
# payload: 4,707 kg
# GTO Orbit
# for None
# result:  Success
#
# Landing: No attempt
# flight_number is 19
# Adding date 28 June 2015
# Adding time 14:21
# Booster Version F9 v1.1[
# Launch Site is Cape Canaveral
# payload:  SpaceX CRS-7
# payload: 1,952 kg
# LEO Orbit
# for NASA
# result:  Failure
# Landing: Precluded
# flight_number is 20
# Adding date 22 December 2015
# Adding time 01:29
# Booster Version F9 FT[
# Launch Site is Cape Canaveral
# payload:  Orbcomm-OG2
# payload: 2,034 kg
# LEO Orbit
# for Orbcomm
# result:  Success
#
# Landing: Success
# flight_number is 21
# Adding date 17 January 2016
# Adding time 18:42
# Booster Version F9 v1.1[
# Launch Site is VAFB
# payload:  Jason-3
# payload: 553 kg
# LEO Orbit
# for NASA
# result:  Success
#
# Landing: Failure
# flight_number is 22
# Adding date 4 March 2016
# Adding time 23:35
# Booster Version F9 FT[
# Launch Site is Cape Canaveral
# payload:  SES-9
# payload: 5,271 kg
# GTO Orbit
# for SES
# result:  Success
#
# Landing: Failure
# flight_number is 23
# Adding date 8 April 2016
# Adding time 20:43
# Booster Version F9 FT[
# Launch Site is Cape Canaveral
# payload:  SpaceX CRS-8
# payload: 3,136 kg
# LEO Orbit
# for NASA
# result:  Success
# Landing: Success
# flight_number is 24
# Adding date 6 May 2016
# Adding time 05:21
# Booster Version F9 FT[
# Launch Site is Cape Canaveral
# payload:  JCSAT-14
# payload: 4,696 kg
# GTO Orbit
# for SKY Perfect JSAT Group
# result:  Success
#
# Landing: Success
# flight_number is 25
# Adding date 27 May 2016
# Adding time 21:39
# Booster Version F9 FT[
# Launch Site is Cape Canaveral
# payload:  Thaicom 8
# payload: 3,100 kg
# GTO Orbit
# for Thaicom
# result:  Success
#
# Landing: Success
# flight_number is 26
# Adding date 15 June 2016
# Adding time 14:29
# Booster Version F9 FT[
# Launch Site is Cape Canaveral
# payload:  ABS-2A
# payload: 3,600 kg
# GTO Orbit
# for ABS
# result:  Success
#
# Landing: Failure
# flight_number is 27
# Adding date 18 July 2016
# Adding time 04:45
# Booster Version F9 FT[
# Launch Site is Cape Canaveral
# payload:  SpaceX CRS-9
# payload: 2,257 kg
# LEO Orbit
# for NASA
# result:  Success
#
# Landing: Success
# flight_number is 28
# Adding date 14 August 2016
# Adding time 05:26
# Booster Version F9 FT[
# Launch Site is Cape Canaveral
# payload:  JCSAT-16
# payload: 4,600 kg
# GTO Orbit
# for SKY Perfect JSAT Group
# result:  Success
#
# Landing: Success
# flight_number is 29
# Adding date 14 January 2017
# Adding time 17:54
# Booster Version F9 FT[
# Launch Site is VAFB
# payload:  Iridium NEXT
# payload: 9,600 kg
# Polar Orbit
# for Iridium Communications
# result:  Success
#
# Landing: Success
# flight_number is 30
# Adding date 19 February 2017
# Adding time 14:39
# Booster Version F9 FT[
# Launch Site is KSC
# payload:  SpaceX CRS-10
# payload: 2,490 kg
# LEO Orbit
# for NASA
# result:  Success
#
# Landing: Success
# flight_number is 31
# Adding date 16 March 2017
# Adding time 06:00
# Booster Version F9 FT[
# Launch Site is KSC
# payload:  EchoStar 23
# payload: 5,600 kg
# GTO Orbit
# for EchoStar
# result:  Success
#
# Landing: No attempt
# flight_number is 32
# Adding date 30 March 2017
# Adding time 22:27
# Booster Version F9 FT♺[
# Launch Site is KSC
# payload:  SES-10
# payload: 5,300 kg
# GTO Orbit
# for SES
# result:  Success
# Landing: Success
# flight_number is 33
# Adding date 1 May 2017
# Adding time 11:15
# Booster Version F9 FT[
# Launch Site is KSC
# payload:  NROL-76
# payload: C
# LEO Orbit
# for NRO
# result:  Success
#
# Landing: Success
# flight_number is 34
# Adding date 15 May 2017
# Adding time 23:21
# Booster Version F9 FT[
# Launch Site is KSC
# payload:  Inmarsat-5 F4
# payload: 6,070 kg
# GTO Orbit
# for Inmarsat
# result:  Success
#
# Landing: No attempt
# flight_number is 35
# Adding date 3 June 2017
# Adding time 21:07
# Booster Version F9 FT[
# Launch Site is KSC
# payload:  SpaceX CRS-11
# payload: 2,708 kg
# LEO Orbit
# for NASA
# result:  Success
#
# Landing: Success
# flight_number is 36
# Adding date 23 June 2017
# Adding time 19:10
# Booster Version F9 FTB1029.2195
# Launch Site is KSC
# payload:  BulgariaSat-1
# payload: 3,669 kg
# GTO Orbit
# for Bulsatcom
# result:  Success
#
# Landing: Success
# flight_number is 37
# Adding date 25 June 2017
# Adding time 20:25
# Booster Version F9 FT[
# Launch Site is VAFB
# payload:  Iridium NEXT
# payload: 9,600 kg
# LEO Orbit
# for Iridium Communications
# result:  Success
#
# Landing: Success
# flight_number is 38
# Adding date 5 July 2017
# Adding time 23:38
# Booster Version F9 FT[
# Launch Site is KSC
# payload:  Intelsat 35e
# payload: 6,761 kg
# GTO Orbit
# for Intelsat
# result:  Success
#
# Landing: No attempt
# flight_number is 39
# Adding date 14 August 2017
# Adding time 16:31
# Booster Version F9 B4[
# Launch Site is KSC
# payload:  SpaceX CRS-12
# payload: 3,310 kg
# LEO Orbit
# for NASA
# result:  Success
#
# Landing: Success
# flight_number is 40
# Adding date 24 August 2017
# Adding time 18:51
# Booster Version F9 FT[
# Launch Site is VAFB
# payload:  Formosat-5
# payload: 475 kg
# SSO Orbit
# for NSPO
# result:  Success
#
# Landing: Success
# flight_number is 41
# Adding date 7 September 2017
# Adding time 14:00
# Booster Version F9 B4[
# Launch Site is KSC
# payload:  Boeing X-37B
# payload: 4,990 kg
# LEO Orbit
# for USAF
# result:  Success
#
# Landing: Success
# flight_number is 42
# Adding date 9 October 2017
# Adding time 12:37
# Booster Version F9 B4[
# Launch Site is VAFB
# payload:  Iridium NEXT
# payload: 9,600 kg
# Polar Orbit
# for Iridium Communications
# result:  Success
#
# Landing: Success
# flight_number is 43
# Adding date 11 October 2017
# Adding time 22:53:00
# Booster Version F9 FTB1031.2220
# Launch Site is KSC
# payload:  SES-11
# payload: 5,200 kg
# GTO Orbit
# for SES S.A.
# result:  Success
#
# Landing: Success
# flight_number is 44
# Adding date 30 October 2017
# Adding time 19:34
# Booster Version F9 B4[
# Launch Site is KSC
# payload:  Koreasat 5A
# payload: 3,500 kg
# GTO Orbit
# for KT Corporation
# result:  Success
#
# Landing: Success
# flight_number is 45
# Adding date 15 December 2017
# Adding time 15:36
# Booster Version F9 FTB1035.2227
# Launch Site is Cape Canaveral
# payload:  SpaceX CRS-13
# payload: 2,205 kg
# LEO Orbit
# for NASA
# result:  Success
#
# Landing: Success
# flight_number is 46
# Adding date 23 December 2017
# Adding time 01:27
# Booster Version F9 FTB1036.2227
# Launch Site is VAFB
# payload:  Iridium NEXT
# payload: 9,600 kg
# Polar Orbit
# for Iridium Communications
# result:  Success
# Landing: Controlled
# flight_number is 47
# Adding date 8 January 2018
# Adding time 01:00
# Booster Version F9 B4[
# Launch Site is CCAFS
# payload:  Zuma
# payload: C
# LEO Orbit
# for Northrop Grumman
# result:  Success
# Landing: Success
# flight_number is 48
# Adding date 31 January 2018
# Adding time 21:25
# Booster Version F9 FTB1032.2245
# Launch Site is CCAFS
# payload:  GovSat-1
# payload: 4,230 kg
# GTO Orbit
# for SES
# result:  Success
# Landing: Controlled
# flight_number is 49
# Adding date 22 February 2018
# Adding time 14:17
# Booster Version F9 FTB1038.2268
# Launch Site is VAFB
# payload:  Paz
# payload: 2,150 kg
# SSO Orbit
# for Hisdesat
# result:  Success
# Landing: No attempt
# flight_number is 50
# Adding date 6 March 2018
# Adding time 05:33
# Booster Version F9 B4[
# Launch Site is CCAFS
# payload:  Hispasat 30W-6
# payload: 6,092 kg
# GTO Orbit
# for Hispasat
# result:  Success
# Landing: No attempt
# flight_number is 51
# Adding date 30 March 2018
# Adding time 14:14
# Booster Version F9 B4B1041.2268
# Launch Site is VAFB
# payload:  Iridium NEXT
# payload: 9,600 kg
# Polar Orbit
# for Iridium Communications
# result:  Success
# Landing: No attempt
# flight_number is 52
# Adding date 2 April 2018
# Adding time 20:30
# Booster Version F9 B4B1039.2292
# Launch Site is CCAFS
# payload:  SpaceX CRS-14
# payload: 2,647 kg
# LEO Orbit
# for NASA
# result:  Success
# Landing: No attempt
# flight_number is 53
# Adding date 18 April 2018
# Adding time 22:51
# Booster Version F9 B4[
# Launch Site is CCAFS
# payload:  Transiting Exoplanet Survey Satellite
# payload: 362 kg
# HEO Orbit
# for NASA
# result:  Success
# Landing: Success
# flight_number is 54
# Adding date 11 May 2018
# Adding time 20:14
# Booster Version F9 B5311B1046.1268
# Launch Site is KSC
# payload:  Bangabandhu-1
# payload: 3,600 kg
# GTO Orbit
# for Thales-Alenia
# result:  Success
# Landing: Success
# flight_number is 55
# Adding date 22 May 2018
# Adding time 19:47
# Booster Version F9 B4B1043.2322
# Launch Site is VAFB
# payload:  Iridium NEXT
# payload: 6,460 kg
# Polar Orbit
# for Iridium Communications
# result:  Success
# Landing: No attempt
# flight_number is 56
# Adding date 4 June 2018
# Adding time 04:45
# Booster Version F9 B4B1040.2268
# Launch Site is CCAFS
# payload:  SES-12
# payload: 5,384 kg
# GTO Orbit
# for SES
# result:  Success
# Landing: No attempt
# flight_number is 57
# Adding date 29 June 2018
# Adding time 09:42
# Booster Version F9 B4B1045.2336
# Launch Site is CCAFS
# payload:  SpaceX CRS-15
# payload: 2,697 kg
# LEO Orbit
# for NASA
# result:  Success
# Landing: No attempt
# flight_number is 58
# Adding date 22 July 2018
# Adding time 05:50
# Booster Version F9 B5
# Launch Site is CCAFS
# payload:  Telstar 19V
# payload: 7,075 kg
# GTO Orbit
# for Telesat
# result:  Success
# Landing: Success
# flight_number is 59
# Adding date 25 July 2018
# Adding time 11:39
# Booster Version F9 B5349B1048[
# Launch Site is VAFB
# payload:  Iridium NEXT
# payload: 9,600 kg
# Polar Orbit
# for Iridium Communications
# result:  Success
# Landing: Success
# flight_number is 60
# Adding date 7 August 2018
# Adding time 05:18
# Booster Version F9 B5B1046.2354
# Launch Site is CCAFS
# payload:  Merah Putih
# payload: 5,800 kg
# GTO Orbit
# for Telkom Indonesia
# result:  Success
# Landing: Success
# flight_number is 61
# Adding date 10 September 2018
# Adding time 04:45
# Booster Version F9 B5[
# Launch Site is CCAFS
# payload:  Telstar 18V
# payload: 7,060 kg
# GTO Orbit
# for Telesat
# result:  Success
# Landing: Success
# flight_number is 62
# Adding date 8 October 2018
# Adding time 02:22
# Booster Version F9 B5B1048.2364
# Launch Site is VAFB
# payload:  SAOCOM 1A
# payload: 3,000 kg
# SSO Orbit
# for CONAE
# result:  Success
# Landing: Success
# flight_number is 63
# Adding date 15 November 2018
# Adding time 20:46
# Booster Version F9 B5B1047.2268
# Launch Site is KSC
# payload:  Es'hail 2
# payload: 5,300 kg
# GTO Orbit
# for Es'hailSat
# result:  Success
# Landing: Success
# flight_number is 64
# Adding date 3 December 2018
# Adding time 18:34:05
# Booster Version F9 B5B1046.3268
# Launch Site is VAFB
# payload:  SSO-A
# payload: ~4,000 kg
# SSO Orbit
# for Spaceflight Industries
# result:  Success
# Landing: Success
# flight_number is 65
# Adding date 5 December 2018
# Adding time 18:16
# Booster Version F9 B5[
# Launch Site is CCAFS
# payload:  SpaceX CRS-16
# payload: 2,500 kg
# LEO Orbit
# for NASA
# result:  Success
#
# Landing: Failure
# flight_number is 66
# Adding date 23 December 2018
# Adding time 13:51
# Booster Version F9 B5[
# Launch Site is CCAFS
# payload:  GPS III
# payload: 4,400 kg
# MEO Orbit
# for USAF
# result:  Success
# Landing: No attempt
# flight_number is 67
# Adding date 11 January 2019
# Adding time 15:31
# Booster Version F9 B5B1049.2397
# Launch Site is VAFB
# payload:  Iridium NEXT
# payload: 9,600 kg
# Polar Orbit
# for Iridium Communications
# result:  Success
#
# Landing: Success
# flight_number is 68
# Adding date 22 February 2019
# Adding time 01:45
# Booster Version F9 B5B1048.3399
# Launch Site is CCAFS
# payload:  Nusantara Satu
# payload: 4,850 kg
# GTO Orbit
# for PSN
# result:  Success
#
# Landing: Success
# flight_number is 69
# Adding date 2 March 2019
# Adding time 07:49
# Booster Version F9 B5[]413
# Launch Site is KSC
# payload:  Crew Dragon Demo-1
# payload: 12,055 kg
# LEO Orbit
# for NASA
# result:  Success
#
# Landing: Success
# flight_number is 70
# Adding date 4 May 2019
# Adding time 06:48
# Booster Version F9 B5[
# Launch Site is CCAFS
# payload:  SpaceX CRS-17
# payload: 2,495 kg
# LEO Orbit
# for NASA
# result:  Success
#
# Landing: Success
# flight_number is 71
# Adding date 24 May 2019
# Adding time 02:30
# Booster Version F9 B5B1049.3434
# Launch Site is CCAFS
# payload:  Starlink
# payload: 13,620 kg
# LEO Orbit
# for SpaceX
# result:  Success
#
# Landing: Success
# flight_number is 72
# Adding date 12 June 2019
# Adding time 14:17
# Booster Version F9 B5B1051.2420
# Launch Site is VAFB
# payload:  RADARSAT Constellation
# payload: 4,200 kg
# SSO Orbit
# for Canadian Space Agency
# result:  Success
#
# Landing: Success
# flight_number is 73
# Adding date 25 July 2019
# Adding time 22:01
# Booster Version F9 B5B1056.2465
# Launch Site is CCAFS
# payload:  SpaceX CRS-18
# payload: 2,268 kg
# LEO Orbit
# for NASA
# result:  Success
#
# Landing: Success
# flight_number is 74
# Adding date 6 August 2019
# Adding time 23:23
# Booster Version F9 B5B1047.3472
# Launch Site is CCAFS
# payload:  AMOS-17
# payload: 6,500 kg
# GTO Orbit
# for Spacecom
# result:  Success
#
# Landing: No attempt
# flight_number is 75
# Adding date 11 November 2019
# Adding time 14:56
# Booster Version F9 B5
# Launch Site is CCAFS
# payload:  Starlink
# payload: 15,600 kg
# LEO Orbit
# for SpaceX
# result:  Success
#
# Landing: Success
# flight_number is 76
# Adding date 5 December 2019
# Adding time 17:29
# Booster Version F9 B5[
# Launch Site is CCAFS
# payload:  SpaceX CRS-19
# payload: 2,617 kg
# LEO Orbit
# for NASA
# result:  Success
#
# Landing: Success
# flight_number is 77
# Adding date 17 December 2019
# Adding time 00:10
# Booster Version F9 B5B1056.3482
# Launch Site is CCAFS
# payload:  JCSat-18
# payload: 6,956 kg
# GTO Orbit
# for Sky Perfect JSAT
# result:  Success
#
# Landing: Success
# flight_number is 78
# Adding date 7 January 2020
# Adding time 02:19:21
# Booster Version F9 B5
# Launch Site is CCAFS
# payload:  Starlink
# payload: 15,600 kg
# LEO Orbit
# for SpaceX
# result:  Success
#
# Landing: Success
# flight_number is 79
# Adding date 19 January 2020
# Adding time 15:30
# Booster Version F9 B5
# Launch Site is KSC
# payload:  Crew Dragon in-flight abort test
# payload: 12,050 kg
# Sub-orbital Orbit
# for NASA
# result:  Success
#
# Landing: No attempt
#
# flight_number is 80
# Adding date 29 January 2020
# Adding time 14:07
# Booster Version F9 B5
# Launch Site is CCAFS
# payload:  Starlink
# payload: 15,600 kg
# LEO Orbit
# for SpaceX
# result:  Success
#
# Landing: Success
# flight_number is 81
# Adding date 17 February 2020
# Adding time 15:05
# Booster Version F9 B5
# Launch Site is CCAFS
# payload:  Starlink
# payload: 15,600 kg
# LEO Orbit
# for SpaceX
# result:  Success
#
# Landing: Failure
# flight_number is 82
# Adding date 7 March 2020
# Adding time 04:50
# Booster Version F9 B5
# Launch Site is CCAFS
# payload:  SpaceX CRS-20
# payload: 1,977 kg
# LEO Orbit
# for NASA
# result:  Success
#
# Landing: Success
# flight_number is 83
# Adding date 18 March 2020
# Adding time 12:16
# Booster Version F9 B5
# Launch Site is KSC
# payload:  Starlink
# payload: 15,600 kg
# LEO Orbit
# for SpaceX
# result:  Success
#
# Landing: Failure
# flight_number is 84
# Adding date 22 April 2020
# Adding time 19:30
# Booster Version F9 B5
# Launch Site is KSC
# payload:  Starlink
# payload: 15,600 kg
# LEO Orbit
# for SpaceX
# result:  Success
#
# Landing: Success
# flight_number is 85
# Adding date 30 May 2020
# Adding time 19:22
# Booster Version F9 B5[
# Launch Site is KSC
# payload:  Crew Dragon Demo-2
# payload: 12,530 kg
# LEO Orbit
# for NASA
# result:  Success
#
# Landing: Success
# flight_number is 86
# Adding date 4 June 2020
# Adding time 01:25
# Booster Version F9 B5
# Launch Site is CCAFS
# payload:  Starlink
# payload: 15,600 kg
# LEO Orbit
# for SpaceX
# result:  Success
#
# Landing: Success
# flight_number is 87
# Adding date 13 June 2020
# Adding time 09:21
# Booster Version F9 B5
# Launch Site is CCAFS
# payload:  Starlink
# payload: 15,410 kg
# LEO Orbit
# for SpaceX
# result:  Success
#
# Landing: Success
# flight_number is 88
# Adding date 30 June 2020
# Adding time 20:10:46
# Booster Version F9 B5
# Launch Site is CCAFS
# payload:  GPS III
# payload: 4,311 kg
# MEO Orbit
# for U.S. Space Force
# result:  Success
#
# Landing: Success
# flight_number is 89
# Adding date 20 July 2020
# Adding time 21:30
# Booster Version F9 B5B1058.2544
# Launch Site is CCAFS
# payload:  ANASIS-II
# payload: 5,000–6,000 kg
# GTO Orbit
# for Republic of Korea Army
# result:  Success
#
# Landing: Success
# flight_number is 90
# Adding date 7 August 2020
# Adding time 05:12
# Booster Version F9 B5
# Launch Site is KSC
# payload:  Starlink
# payload: 14,932 kg
# LEO Orbit
# for SpaceX
# result:  Success
#
# Landing: Success
# flight_number is 91
# Adding date 18 August 2020
# Adding time 14:31
# Booster Version F9 B5B1049.6544
# Launch Site is CCAFS
# payload:  Starlink
# payload: ~15,440 kg
# LEO Orbit
# for SpaceX
# result:  Success
#
# Landing: Success
# flight_number is 92
# Adding date 30 August 2020
# Adding time 23:18
# Booster Version F9 B5
# Launch Site is CCAFS
# payload:  SAOCOM 1B
# payload: 3,130 kg
# SSO Orbit
# for CONAE
# result:  Success
#
# Landing: Success
# flight_number is 93
# Adding date 3 September 2020
# Adding time 12:46:14
# Booster Version F9 B5B1060.2563
# Launch Site is KSC
# payload:  Starlink
# payload: 15,600 kg
# LEO Orbit
# for SpaceX
# result:  Success
#
# Landing: Success
# flight_number is 94
# Adding date 6 October 2020
# Adding time 11:29:34
# Booster Version F9 B5B1058.3565
# Launch Site is KSC
# payload:  Starlink
# payload: 15,600 kg
# LEO Orbit
# for SpaceX
# result:  Success
#
# Landing: Success
# flight_number is 95
# Adding date 18 October 2020
# Adding time 12:25:57
# Booster Version F9 B5B1051.6568
# Launch Site is KSC
# payload:  Starlink
# payload: 15,600 kg
# LEO Orbit
# for SpaceX
# result:  Success
#
# Landing: Success
# flight_number is 96
# Adding date 24 October 2020
# Adding time 15:31:34
# Booster Version F9 B5
# Launch Site is CCAFS
# payload:  Starlink
# payload: 15,600 kg
# LEO Orbit
# for SpaceX
# result:  Success
#
# Landing: Success
# flight_number is 97
# Adding date 5 November 2020
# Adding time 23:24:23
# Booster Version F9 B5
# Launch Site is CCAFS
# payload:  GPS III
# payload: 4,311 kg
# MEO Orbit
# for USSF
# result:  Success
#
# Landing: Success
# flight_number is 98
# Adding date 16 November 2020
# Adding time 00:27
# Booster Version F9 B5[
# Launch Site is KSC
# payload:  Crew-1
# payload: ~12,500 kg
# LEO Orbit
# for NASA
# result:  Success
#
# Landing: Success
# flight_number is 99
# Adding date 21 November 2020
# Adding time 17:17:08
# Booster Version F9 B5
# Launch Site is VAFB
# payload:  Sentinel-6 Michael Freilich (Jason-CS A)
# payload: 1,192 kg
# LEO Orbit
# for NASA
# result:  Success
#
# Landing: Success
# flight_number is 100
# Adding date 25 November 2020
# Adding time 02:13
# Booster Version F9 B5 ♺[
# Launch Site is CCAFS
# payload:  Starlink
# payload: 15,600 kg
# LEO Orbit
# for SpaceX
# result:  Success
#
# Landing: Success
# flight_number is 101
# Adding date 6 December 2020
# Adding time 16:17:08
# Booster Version F9 B5 ♺[
# Launch Site is KSC
# payload:  SpaceX CRS-21
# payload: 2,972 kg
# LEO Orbit
# for NASA
# result:  Success
#
# Landing: Success
# flight_number is 102
# Adding date 13 December 2020
# Adding time 17:30:00
# Booster Version F9 B5 ♺
# Launch Site is CCSFS
# payload:  SXM-7
# payload: 7,000 kg
# GTO Orbit
# for Sirius XM
# result:  Success
#
# Landing: Success
# flight_number is 103
# Adding date 19 December 2020
# Adding time 14:00:00
# Booster Version F9 B5 ♺
# Launch Site is KSC
# payload:  NROL-108
# payload: C
# LEO Orbit
# for NRO
# result:  Success
#
# Landing: Success
# flight_number is 104
# Adding date 8 January 2021
# Adding time 02:15
# Booster Version F9 B5
# Launch Site is CCSFS
# payload:  Türksat 5A
# payload: 3,500 kg
# GTO Orbit
# for Türksat
# result:  Success
#
# Landing: Success
# flight_number is 105
# Adding date 20 January 2021
# Adding time 13:02
# Booster Version F9 B5B1051.8609
# Launch Site is KSC
# payload:  Starlink
# payload: 15,600 kg
# LEO Orbit
# for SpaceX
# result:  Success
#
# Landing: Success
# flight_number is 106
# Adding date 24 January 2021
# Adding time 15:00
# Booster Version F9 B5B1058.5613
# Launch Site is CCSFS
# payload:  Transporter-1
# payload: ~5,000 kg
# SSO Orbit
# for Various
#
# result:  Success
#
# Landing: Success
# flight_number is 107
# Adding date 4 February 2021
# Adding time 06:19
# Booster Version F9 B5 ♺[
# Launch Site is CCSFS
# payload:  Starlink
# payload: 15,600 kg
# LEO Orbit
# for SpaceX
# result:  Success
#
# Landing: Success
# flight_number is 108
# Adding date 16 February 2021
# Adding time 03:59:37
# Booster Version F9 B5 ♺
# Launch Site is CCSFS
# payload:  Starlink
# payload: 15,600 kg
# LEO Orbit
# for SpaceX
# result:  Success
#
# Landing: Failure
# flight_number is 109
# Adding date 4 March 2021
# Adding time 08:24
# Booster Version F9 B5 ♺[
# Launch Site is KSC
# payload:  Starlink
# payload: 15,600 kg
# LEO Orbit
# for SpaceX
# result:  Success
#
# Landing: Success
# flight_number is 110
# Adding date 11 March 2021
# Adding time 08:13:29
# Booster Version F9 B5 ♺[
# Launch Site is CCSFS
# payload:  Starlink
# payload: 15,600 kg
# LEO Orbit
# for SpaceX
# result:  Success
#
# Landing: Success
# flight_number is 111
# Adding date 14 March 2021
# Adding time 10:01
# Booster Version F9 B5 ♺
# Launch Site is KSC
# payload:  Starlink
# payload: 15,600 kg
# LEO Orbit
# for SpaceX
# result:  Success
#
# Landing: Success
# flight_number is 112
# Adding date 24 March 2021
# Adding time 08:28
# Booster Version F9 B5B1060.6643
# Launch Site is CCSFS
# payload:  Starlink
# payload: 15,600 kg
# LEO Orbit
# for SpaceX
# result:  Success
#
# Landing: Success
# flight_number is 113
# Adding date 7 April 2021
# Adding time 16:34
# Booster Version F9 B5 ♺
# Launch Site is CCSFS
# payload:  Starlink
# payload: 15,600 kg
# LEO Orbit
# for SpaceX
# result:  Success
#
# Landing: Success
# flight_number is 114
# Adding date 23 April 2021
# Adding time 9:49
# Booster Version F9 B5B1061.2647
# Launch Site is KSC
# payload:  Crew-2
# payload: ~13,000 kg
# LEO Orbit
# for NASA
# result:  Success
#
# Landing: Success
# flight_number is 115
# Adding date 29 April 2021
# Adding time 03:44
# Booster Version F9 B5B1060.7652
# Launch Site is CCSFS
# payload:  Starlink
# payload: 15,600 kg
# LEO Orbit
# for SpaceX
# result:  Success
#
# Landing: Success
# flight_number is 116
# Adding date 4 May 2021
# Adding time 19:01
# Booster Version F9 B5B1049.9655
# Launch Site is KSC
# payload:  Starlink
# payload: 15,600 kg
# LEO Orbit
# for SpaceX
# result:  Success
#
# Landing: Success
# flight_number is 117
# Adding date 9 May 2021
# Adding time 06:42
# Booster Version F9 B5B1051.10657
# Launch Site is CCSFS
# payload:  Starlink
# payload: 15,600 kg
# LEO Orbit
# for SpaceX
# result:  Success
#
# Landing: Success
# flight_number is 118
# Adding date 15 May 2021
# Adding time 22:56
# Booster Version F9 B5B1058.8660
# Launch Site is KSC
# payload:  Starlink
# payload: ~14,000 kg
# LEO Orbit
# for SpaceX
# result:  Success
#
# Landing: Success
# flight_number is 119
# Adding date 26 May 2021
# Adding time 18:59
# Booster Version F9 B5B1063.2665
# Launch Site is CCSFS
# payload:  Starlink
# payload: 15,600 kg
# LEO Orbit
# for SpaceX
# result:  Success
#
# Landing: Success
# flight_number is 120
# Adding date 3 June 2021
# Adding time 17:29
# Booster Version F9 B5B1067.1668
# Launch Site is KSC
# payload:  SpaceX CRS-22
# payload: 3,328 kg
# LEO Orbit
# for NASA
# result:  Success
#
# Landing: Success
# flight_number is 121
# Adding date 6 June 2021
# Adding time 04:26
# Booster Version F9 B5
# Launch Site is CCSFS
# payload:  SXM-8
# payload: 7,000 kg
# GTO Orbit
# for Sirius XM
# result:  Success
#
# Landing: Success

# %% [markdown]
# After you have fill in the parsed launch record values into `launch_dict`, you can create a dataframe from it.

# %%
df= pd.DataFrame({ key:pd.Series(value) for key, value in launch_dict.items() })

# %% [markdown]
# We can now export it to a <b>CSV</b> for the next section, but to make the answers consistent and in case you have difficulties finishing this lab.
#
# Following labs will be using a provided dataset to make each lab independent.

# %%
df.to_csv('spacex_web_scraped.csv', index=False)

# %% [markdown]
# ## Authors

# %% [markdown]
# <a href="https://www.linkedin.com/in/yan-luo-96288783/">Yan Luo</a>

# %% [markdown]
# <a href="https://www.linkedin.com/in/nayefaboutayoun/">Nayef Abou Tayoun</a>

# %% [markdown]
# <!--
# ## Change Log
# -->

# %% [markdown]
# <!--
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description      |
# | ----------------- | ------- | ---------- | ----------------------- |
# | 2021-06-09        | 1.0     | Yan Luo    | Tasks updates           |
# | 2020-11-10        | 1.0     | Nayef      | Created the initial version |
# -->

# %% [markdown]
# Copyright © 2021 IBM Corporation. All rights reserved.
